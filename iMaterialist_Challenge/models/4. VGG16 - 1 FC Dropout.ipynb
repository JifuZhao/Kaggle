# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
import random, gc, keras, os

from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Input
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Dataset

# %%
train_df = pd.read_csv('./data/train.csv')
val_df = pd.read_csv('./data/validation.csv')
test_df = pd.read_csv('./data/test.csv')

print('Train:\t\t', train_df.shape, '\t', len(train_df['label'].unique()))
print('Validation:\t', val_df.shape, '\t', len(val_df['label'].unique()))
print('Test:\t\t', test_df.shape)
# Out:
# Train:		 (194828, 3) 	 128
# Validation:	 (6400, 3) 	 128
# Test:		 (12800, 2)

# %%
train_df.head()
# Out:
#    id  label                                                url
# 0   1      5  https://img13.360buyimg.com/imgzone/jfs/t2857/...
# 1   2      5  http://www.tengdakeli.cn/350/timg01/uploaded/i...
# 2   3      5  https://img13.360buyimg.com/imgzone/jfs/t8899/...
# 3   4      5  http://img4.tbcdn.cn/tfscom/i1/2855447419/TB2S...
# 4   5      5  http://a.vpimg4.com/upload/merchandise/287883/...

# %%
# Helper function
train_dir = './data/train'
val_dir = './data/validation'
test_dir = './data/test'

def lr_schedule(epoch):
    """ Learning rate schedule """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# # VGG16

# %%
# For reproduciable purpose
seed = 42
K.clear_session()
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(seed)
random.seed(seed)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.set_random_seed(seed)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# Define parameters
classes = [str(i) for i in range(1, 129)]

# define image generator
train_gen = ImageDataGenerator(rescale=1.0/255)
train_generator = train_gen.flow_from_directory(train_dir, batch_size=160, classes=classes, 
                                                target_size=(224, 224))

val_gen = ImageDataGenerator(rescale=1.0/255)
val_generator = val_gen.flow_from_directory(val_dir, batch_size=286, classes=classes, 
                                            target_size=(224, 224))
# Out:
# Found 191680 images belonging to 128 classes.
# Found 6292 images belonging to 128 classes.

# %% [markdown]
# ### Initial training

# %%
# Load pre-trained VGG16
vgg16_base = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224, 3))

# Define new CNN models
vgg16 = Sequential()
vgg16.add(vgg16_base)
vgg16.add(Flatten(name='flatten'))
vgg16.add(Dropout(rate=0.5, name='dropout'))
vgg16.add(Dense(128, activation='softmax', name='prediction'))

# Make base model untrainable
vgg16_base.trainable = False

# Model summary
vgg16.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 25088)             0
# _________________________________________________________________
# prediction (Dense)           (None, 128)               3211392
# =================================================================
# Total params: 17,926,080
# Trainable params: 3,211,392
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Compile the model
opt = keras.optimizers.Adam(lr=lr_schedule(0))
vgg16.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Create call backs
checkpoint = ModelCheckpoint(filepath='./models/vgg16-1-layer-dropout-initial.h5', verbose=0, 
                             monitor='val_acc', save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# fit the mode
history = vgg16.fit_generator(train_generator, steps_per_epoch=100, epochs=100, verbose=2, 
                              callbacks=callbacks, validation_data=val_generator, validation_steps=22)
_ = gc.collect()
# Out:
# Learning rate:  0.001
# Epoch 1/100
# Learning rate:  0.001
#  - 218s - loss: 2.8584 - acc: 0.3584 - val_loss: 2.1217 - val_acc: 0.4900
# Epoch 2/100
# Learning rate:  0.001
#  - 211s - loss: 1.9868 - acc: 0.5182 - val_loss: 1.9088 - val_acc: 0.5478
# Epoch 3/100
# Learning rate:  0.001
#  - 199s - loss: 1.8103 - acc: 0.5591 - val_loss: 1.8571 - val_acc: 0.5779
# Epoch 4/100
# Learning rate:  0.001
#  - 196s - loss: 1.7929 - acc: 0.5764 - val_loss: 1.8830 - val_acc: 0.5722
# Epoch 5/100
# Learning rate:  0.001
#  - 195s - loss: 1.8116 - acc: 0.5826 - val_loss: 1.6966 - val_acc: 0.6006
# Epoch 6/100
# Learning rate:  0.001
#  - 204s - loss: 1.7542 - acc: 0.5985 - val_loss: 1.7262 - val_acc: 0.6074
# Epoch 7/100
# Learning rate:  0.001
#  - 202s - loss: 1.7551 - acc: 0.6053 - val_loss: 1.7062 - val_acc: 0.6147
# Epoch 8/100
# Learning rate:  0.001
#  - 210s - loss: 1.7502 - acc: 0.6113 - val_loss: 1.7101 - val_acc: 0.6244
# Epoch 9/100
# Learning rate:  0.001
#  - 198s - loss: 1.7743 - acc: 0.6096 - val_loss: 1.7321 - val_acc: 0.6305
# Epoch 10/100
# Learning rate:  0.001
#  - 197s - loss: 1.7352 - acc: 0.6203 - val_loss: 1.6700 - val_acc: 0.6348
# Epoch 11/100
# Learning rate:  0.001
#  - 196s - loss: 1.7868 - acc: 0.6177 - val_loss: 1.7734 - val_acc: 0.6238
# Epoch 12/100
# Learning rate:  0.001
#  - 195s - loss: 1.7994 - acc: 0.6178 - val_loss: 1.7560 - val_acc: 0.6297
# Epoch 13/100
# Learning rate:  0.001
#  - 194s - loss: 1.1579 - acc: 0.7143 - val_loss: 1.5912 - val_acc: 0.6503
# Epoch 14/100
# Learning rate:  0.001
#  - 195s - loss: 1.2182 - acc: 0.7023 - val_loss: 1.6906 - val_acc: 0.6426
# Epoch 15/100
# Learning rate:  0.001
#  - 197s - loss: 1.2648 - acc: 0.6949 - val_loss: 1.6974 - val_acc: 0.6414
# Epoch 16/100
# Learning rate:  0.001
#  - 197s - loss: 1.3298 - acc: 0.6903 - val_loss: 1.6574 - val_acc: 0.6515
# Epoch 17/100
# Learning rate:  0.001
#  - 197s - loss: 1.3474 - acc: 0.6817 - val_loss: 1.6837 - val_acc: 0.6469
# Epoch 18/100
# Learning rate:  0.001
#  - 197s - loss: 1.3748 - acc: 0.6877 - val_loss: 1.7007 - val_acc: 0.6531
# Epoch 19/100
# Learning rate:  0.001
#  - 196s - loss: 1.3849 - acc: 0.6882 - val_loss: 1.7743 - val_acc: 0.6526
# Epoch 20/100
# Learning rate:  0.001
#  - 196s - loss: 1.3902 - acc: 0.6887 - val_loss: 1.7552 - val_acc: 0.6492
# Epoch 21/100
# Learning rate:  0.001
#  - 204s - loss: 1.4397 - acc: 0.6827 - val_loss: 1.7674 - val_acc: 0.6540
# Epoch 22/100
# Learning rate:  0.001
#  - 198s - loss: 1.4667 - acc: 0.6827 - val_loss: 1.7254 - val_acc: 0.6570
# Epoch 23/100
# Learning rate:  0.001
#  - 197s - loss: 1.5154 - acc: 0.6740 - val_loss: 1.6923 - val_acc: 0.6564
# Epoch 24/100
# Learning rate:  0.001
#  - 196s - loss: 1.4672 - acc: 0.6894 - val_loss: 1.7566 - val_acc: 0.6585
# Epoch 25/100
# Learning rate:  0.001
#  - 201s - loss: 1.0344 - acc: 0.7505 - val_loss: 1.7487 - val_acc: 0.6532
# Epoch 26/100
# Learning rate:  0.001
#  - 196s - loss: 1.0815 - acc: 0.7439 - val_loss: 1.7582 - val_acc: 0.6599
# Epoch 27/100
# Learning rate:  0.001
#  - 196s - loss: 1.0832 - acc: 0.7396 - val_loss: 1.7304 - val_acc: 0.6666
# Epoch 28/100
# Learning rate:  0.001
#  - 197s - loss: 1.1436 - acc: 0.7335 - val_loss: 1.7780 - val_acc: 0.6556
# Epoch 29/100
# Learning rate:  0.001
#  - 199s - loss: 1.1524 - acc: 0.7267 - val_loss: 1.7903 - val_acc: 0.6621
# Epoch 30/100
# Learning rate:  0.001
#  - 196s - loss: 1.2276 - acc: 0.7209 - val_loss: 1.8111 - val_acc: 0.6516
# Epoch 31/100
# Learning rate:  0.001
#  - 198s - loss: 1.2351 - acc: 0.7208 - val_loss: 1.7748 - val_acc: 0.6610
# Epoch 32/100
# Learning rate:  0.001
#  - 198s - loss: 1.2737 - acc: 0.7196 - val_loss: 1.7965 - val_acc: 0.6553
# Epoch 33/100
# Learning rate:  0.001
#  - 203s - loss: 1.2675 - acc: 0.7221 - val_loss: 1.8657 - val_acc: 0.6524
# Epoch 34/100
# Learning rate:  0.001
#  - 197s - loss: 1.3269 - acc: 0.7149 - val_loss: 1.8265 - val_acc: 0.6597
# Epoch 35/100
# Learning rate:  0.001
#  - 197s - loss: 1.3528 - acc: 0.7116 - val_loss: 1.8899 - val_acc: 0.6608
# Epoch 36/100
# Learning rate:  0.001
#  - 197s - loss: 1.3287 - acc: 0.7174 - val_loss: 1.8599 - val_acc: 0.6656
# Epoch 37/100
# Learning rate:  0.001
#  - 195s - loss: 0.9528 - acc: 0.7753 - val_loss: 1.7958 - val_acc: 0.6748
# Epoch 38/100
# Learning rate:  0.001
#  - 198s - loss: 0.9785 - acc: 0.7680 - val_loss: 1.7611 - val_acc: 0.6748
# Epoch 39/100
# Learning rate:  0.001
#  - 196s - loss: 0.9930 - acc: 0.7657 - val_loss: 1.8803 - val_acc: 0.6589
# Epoch 40/100
# Learning rate:  0.001
#  - 196s - loss: 1.0751 - acc: 0.7559 - val_loss: 1.9266 - val_acc: 0.6624
# Epoch 41/100
# Learning rate:  0.001
#  - 199s - loss: 1.0968 - acc: 0.7522 - val_loss: 1.8470 - val_acc: 0.6694
# Epoch 42/100
# Learning rate:  0.001
#  - 199s - loss: 1.1127 - acc: 0.7512 - val_loss: 1.8894 - val_acc: 0.6677
# Epoch 43/100
# Learning rate:  0.001
#  - 194s - loss: 1.1376 - acc: 0.7482 - val_loss: 1.8940 - val_acc: 0.6712
# Epoch 44/100
# Learning rate:  0.001
#  - 201s - loss: 1.1991 - acc: 0.7378 - val_loss: 1.9542 - val_acc: 0.6616
# Epoch 45/100
# Learning rate:  0.001
#  - 214s - loss: 1.2113 - acc: 0.7358 - val_loss: 1.8636 - val_acc: 0.6771
# Epoch 46/100
# Learning rate:  0.001
#  - 198s - loss: 1.2854 - acc: 0.7333 - val_loss: 2.0023 - val_acc: 0.6596
# Epoch 47/100
# Learning rate:  0.001
#  - 194s - loss: 1.2614 - acc: 0.7315 - val_loss: 1.9007 - val_acc: 0.6767
# Epoch 48/100
# Learning rate:  0.001
#  - 200s - loss: 1.2841 - acc: 0.7339 - val_loss: 1.9106 - val_acc: 0.6828
# Epoch 49/100
# Learning rate:  0.001
#  - 201s - loss: 0.9307 - acc: 0.7797 - val_loss: 1.9481 - val_acc: 0.6734
# Epoch 50/100
# Learning rate:  0.001
#  - 196s - loss: 0.9715 - acc: 0.7761 - val_loss: 1.9369 - val_acc: 0.6759
# Epoch 51/100
# Learning rate:  0.001
#  - 196s - loss: 0.9422 - acc: 0.7818 - val_loss: 1.9922 - val_acc: 0.6667
# Epoch 52/100
# Learning rate:  0.001
#  - 198s - loss: 1.0241 - acc: 0.7716 - val_loss: 2.0543 - val_acc: 0.6620
# Epoch 53/100
# Learning rate:  0.001
#  - 200s - loss: 1.0153 - acc: 0.7756 - val_loss: 1.9850 - val_acc: 0.6693
# Epoch 54/100
# Learning rate:  0.001
#  - 197s - loss: 1.0521 - acc: 0.7693 - val_loss: 1.9741 - val_acc: 0.6716
# Epoch 55/100
# Learning rate:  0.001
#  - 197s - loss: 1.1246 - acc: 0.7558 - val_loss: 2.1253 - val_acc: 0.6658
# Epoch 56/100
# Learning rate:  0.001
#  - 200s - loss: 1.1094 - acc: 0.7634 - val_loss: 1.9474 - val_acc: 0.6780
# Epoch 57/100
# Learning rate:  0.001
#  - 208s - loss: 1.1300 - acc: 0.7594 - val_loss: 2.0622 - val_acc: 0.6748
# Epoch 58/100
# Learning rate:  0.001
#  - 199s - loss: 1.1741 - acc: 0.7531 - val_loss: 1.9978 - val_acc: 0.6748
# Epoch 59/100
# Learning rate:  0.001
#  - 203s - loss: 1.1504 - acc: 0.7592 - val_loss: 2.0731 - val_acc: 0.6645
# Epoch 60/100
# Learning rate:  0.001
#  - 197s - loss: 1.1625 - acc: 0.7587 - val_loss: 1.9039 - val_acc: 0.6863
# Epoch 61/100
# Learning rate:  0.001
#  - 197s - loss: 0.8722 - acc: 0.7991 - val_loss: 2.0859 - val_acc: 0.6747
# Epoch 62/100
# Learning rate:  0.001
#  - 193s - loss: 0.9066 - acc: 0.7944 - val_loss: 2.0908 - val_acc: 0.6732
# Epoch 63/100
# Learning rate:  0.001
#  - 209s - loss: 0.8707 - acc: 0.7998 - val_loss: 2.0702 - val_acc: 0.6840
# Epoch 64/100
# Learning rate:  0.001
#  - 200s - loss: 0.9760 - acc: 0.7861 - val_loss: 2.0640 - val_acc: 0.6763
# Epoch 65/100
# Learning rate:  0.001
#  - 195s - loss: 0.9861 - acc: 0.7854 - val_loss: 2.1186 - val_acc: 0.6736
# Epoch 66/100
# Learning rate:  0.001
#  - 202s - loss: 1.0192 - acc: 0.7809 - val_loss: 2.1820 - val_acc: 0.6651
# Epoch 67/100
# Learning rate:  0.001
#  - 196s - loss: 1.0735 - acc: 0.7687 - val_loss: 2.0707 - val_acc: 0.6763
# Epoch 68/100
# Learning rate:  0.001
#  - 196s - loss: 1.0756 - acc: 0.7725 - val_loss: 2.0261 - val_acc: 0.6788
# Epoch 69/100
# Learning rate:  0.001
#  - 198s - loss: 1.1163 - acc: 0.7684 - val_loss: 2.1210 - val_acc: 0.6753
# Epoch 70/100
# Learning rate:  0.001
#  - 198s - loss: 1.1479 - acc: 0.7622 - val_loss: 2.1438 - val_acc: 0.6750
# Epoch 71/100
# Learning rate:  0.001
#  - 201s - loss: 1.1253 - acc: 0.7682 - val_loss: 2.0311 - val_acc: 0.6855
# Epoch 72/100
# Learning rate:  0.001
#  - 196s - loss: 1.0909 - acc: 0.7735 - val_loss: 2.1272 - val_acc: 0.6742
# Epoch 73/100
# Learning rate:  0.001
#  - 197s - loss: 0.8561 - acc: 0.8115 - val_loss: 2.0089 - val_acc: 0.6896
# Epoch 74/100
# Learning rate:  0.001
#  - 200s - loss: 0.8617 - acc: 0.8072 - val_loss: 2.1208 - val_acc: 0.6750
# Epoch 75/100
# Learning rate:  0.001
#  - 197s - loss: 0.9016 - acc: 0.8030 - val_loss: 2.1664 - val_acc: 0.6766
# Epoch 76/100
# Learning rate:  0.001
#  - 199s - loss: 0.9144 - acc: 0.8000 - val_loss: 2.1792 - val_acc: 0.6750
# Epoch 77/100
# Learning rate:  0.001
#  - 198s - loss: 0.8969 - acc: 0.8018 - val_loss: 2.1548 - val_acc: 0.6764
# Epoch 78/100
# Learning rate:  0.001
#  - 197s - loss: 0.9889 - acc: 0.7916 - val_loss: 2.2990 - val_acc: 0.6626
# Epoch 79/100
# Learning rate:  0.001
#  - 201s - loss: 0.9696 - acc: 0.7907 - val_loss: 2.1803 - val_acc: 0.6761
# Epoch 80/100
# Learning rate:  0.001
#  - 194s - loss: 1.0416 - acc: 0.7850 - val_loss: 2.2169 - val_acc: 0.6775
# Epoch 81/100
# Learning rate:  0.001
#  - 194s - loss: 1.0290 - acc: 0.7851 - val_loss: 2.1597 - val_acc: 0.6853
# Epoch 82/100
# Learning rate:  0.0001
#  - 198s - loss: 0.8721 - acc: 0.8064 - val_loss: 1.9055 - val_acc: 0.7092
# Epoch 83/100
# Learning rate:  0.0001
#  - 199s - loss: 0.8565 - acc: 0.8126 - val_loss: 1.8939 - val_acc: 0.7082
# Epoch 84/100
# Learning rate:  0.0001
#  - 196s - loss: 0.8099 - acc: 0.8223 - val_loss: 1.9018 - val_acc: 0.7071
# Epoch 85/100
# Learning rate:  0.0001
#  - 199s - loss: 0.6136 - acc: 0.8501 - val_loss: 1.9012 - val_acc: 0.7068
# Epoch 86/100
# Learning rate:  0.0001
#  - 197s - loss: 0.6026 - acc: 0.8537 - val_loss: 1.8664 - val_acc: 0.7106
# Epoch 87/100
# Learning rate:  0.0001
#  - 196s - loss: 0.6126 - acc: 0.8562 - val_loss: 1.8633 - val_acc: 0.7115
# Epoch 88/100
# Learning rate:  0.0001
#  - 198s - loss: 0.6247 - acc: 0.8484 - val_loss: 1.8966 - val_acc: 0.7077
# Epoch 89/100
# Learning rate:  0.0001
#  - 196s - loss: 0.6061 - acc: 0.8506 - val_loss: 1.8685 - val_acc: 0.7112
# Epoch 90/100
# Learning rate:  0.0001
#  - 211s - loss: 0.6186 - acc: 0.8517 - val_loss: 1.8627 - val_acc: 0.7099
# Epoch 91/100
# Learning rate:  0.0001
#  - 195s - loss: 0.5753 - acc: 0.8556 - val_loss: 1.8674 - val_acc: 0.7117
# Epoch 92/100
# Learning rate:  0.0001
#  - 212s - loss: 0.6042 - acc: 0.8538 - val_loss: 1.8525 - val_acc: 0.7122
# Epoch 93/100
# Learning rate:  0.0001
#  - 196s - loss: 0.6057 - acc: 0.8503 - val_loss: 1.8346 - val_acc: 0.7141
# Epoch 94/100
# Learning rate:  0.0001
#  - 203s - loss: 0.5955 - acc: 0.8544 - val_loss: 1.8594 - val_acc: 0.7142
# Epoch 95/100
# Learning rate:  0.0001
#  - 199s - loss: 0.5972 - acc: 0.8544 - val_loss: 1.8360 - val_acc: 0.7109
# Epoch 96/100
# Learning rate:  0.0001
#  - 200s - loss: 0.5720 - acc: 0.8594 - val_loss: 1.8250 - val_acc: 0.7160
# Epoch 97/100
# Learning rate:  0.0001
#  - 195s - loss: 0.5314 - acc: 0.8646 - val_loss: 1.8503 - val_acc: 0.7107
# Epoch 98/100
# Learning rate:  0.0001
#  - 198s - loss: 0.5690 - acc: 0.8575 - val_loss: 1.8401 - val_acc: 0.7133
# Epoch 99/100
# Learning rate:  0.0001
#  - 196s - loss: 0.5717 - acc: 0.8625 - val_loss: 1.8315 - val_acc: 0.7138
# Epoch 100/100
# Learning rate:  0.0001
#  - 209s - loss: 0.5306 - acc: 0.8621 - val_loss: 1.8321 - val_acc: 0.7136

# %%
# Visualize the training process
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 7))
ax[0].plot(train_loss, label='Training Loss')
ax[0].plot(val_loss, label='Validation Loss')
ax[0].set_title('Loss vs. Epochs', fontsize=16)
ax[0].set_xlabel('Epochs', fontsize=14)
ax[0].set_ylabel('Loss', fontsize=14)
ax[0].legend(fontsize=14)
ax[0].grid(True)

ax[1].plot(train_acc, label='Train Accuracy')
ax[1].plot(val_acc, label='Val Accuracy')
ax[1].set_title('Accuracy vs. Epochs', fontsize=16)
ax[1].set_xlabel('Epochs', fontsize=14)
ax[1].set_ylabel('Accuracy', fontsize=14)
ax[1].legend(fontsize=14)
ax[1].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Make Predictions

# %%
# Load test images
test_ids = []
test_images = []
for idx in test_df['id'].values:
    if os.path.exists('./data/test/' + str(idx) + '.jpg'):
        img = Image.open('./data/test/' + str(idx) + '.jpg')
        if img.mode != 'RGB':
            img = img.convert('RGB')
        img = img.resize((224, 224))
        img = np.asarray(img, dtype=K.floatx())
        test_images.append(img)
        test_ids.append(idx)

# Re-scale the images
test_images = np.array(test_images, dtype=K.floatx())
test_images = test_images / 255.0

# %%
# Load the saved model
vgg16 = load_model('./models/vgg16-1-layer-dropout-initial.h5')

# Make predictions
test_pred = vgg16.predict(test_images)
test_label = np.argmax(test_pred, axis=1) + 1

# %%
# Sample submission
sample_submission = pd.read_csv('./data/sample_submission.csv', usecols=['id'])
df_submission = pd.DataFrame({'id': test_ids, 'predicted': test_label})

# Merge together
df_submission = pd.merge(sample_submission, df_submission, how='left', on='id')

# Fill missing values
n = df_submission['predicted'].isnull().sum()
guess = np.random.choice(range(1, 129), n, replace=True)
df_submission.loc[df_submission['predicted'].isnull(), 'predicted'] = guess
df_submission['predicted'] = df_submission['predicted'].astype(int)

# Save to disk
df_submission.to_csv('./result/vgg16-1-layer-dropout-initial.csv', columns=['id', 'predicted'], index=False)

_ = gc.collect()

# %% [markdown]
# # VGG16 Fune-tuning
