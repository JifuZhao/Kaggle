# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
import random, gc, keras, os

from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, AveragePooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Dataset

# %%
train_df = pd.read_csv('./data/train.csv')
val_df = pd.read_csv('./data/validation.csv')
test_df = pd.read_csv('./data/test.csv')

print('Train:\t\t', train_df.shape, '\t', len(train_df['label'].unique()))
print('Validation:\t', val_df.shape, '\t', len(val_df['label'].unique()))
print('Test:\t\t', test_df.shape)
# Out:
# Train:		 (194828, 3) 	 128
# Validation:	 (6400, 3) 	 128
# Test:		 (12800, 2)

# %%
train_df.head()
# Out:
#    id  label                                                url
# 0   1      5  https://img13.360buyimg.com/imgzone/jfs/t2857/...
# 1   2      5  http://www.tengdakeli.cn/350/timg01/uploaded/i...
# 2   3      5  https://img13.360buyimg.com/imgzone/jfs/t8899/...
# 3   4      5  http://img4.tbcdn.cn/tfscom/i1/2855447419/TB2S...
# 4   5      5  http://a.vpimg4.com/upload/merchandise/287883/...

# %%
# Helper function
train_dir = './data/train'
val_dir = './data/validation'
test_dir = './data/test'

def lr_schedule(epoch):
    """ Learning rate schedule """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %% [markdown]
# # VGG16

# %%
# For reproduciable purpose
seed = 42
K.clear_session()
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(seed)
random.seed(seed)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
tf.set_random_seed(seed)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# Define parameters
classes = [str(i) for i in range(1, 129)]

# define image generator
train_gen = ImageDataGenerator(rescale=1.0/255)
train_generator = train_gen.flow_from_directory(train_dir, batch_size=160, classes=classes, 
                                                target_size=(224, 224))

val_gen = ImageDataGenerator(rescale=1.0/255)
val_generator = val_gen.flow_from_directory(val_dir, batch_size=286, classes=classes, 
                                            target_size=(224, 224))
# Out:
# Found 191680 images belonging to 128 classes.
# Found 6292 images belonging to 128 classes.

# %% [markdown]
# ### Initial training

# %%
# Load pre-trained VGG16
vgg16_base = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224, 3))

# Define new CNN models
vgg16 = Sequential()
vgg16.add(vgg16_base)
vgg16.add(Flatten(name='flatten'))
vgg16.add(Dense(128, activation='softmax', name='prediction'))

# Make base model untrainable
vgg16_base.trainable = False

# Model summary
vgg16.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# prediction (Dense)           (None, 128)               3211392
# =================================================================
# Total params: 17,926,080
# Trainable params: 3,211,392
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Compile the model
opt = keras.optimizers.Adam(lr=lr_schedule(0))
vgg16.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Create call backs
checkpoint = ModelCheckpoint(filepath='./models/vgg16-1-layer-initial.h5', verbose=0, 
                             monitor='val_acc', save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), cooldown=0, patience=5, min_lr=0.5e-6)
callbacks = [checkpoint, lr_reducer, lr_scheduler]

# fit the mode
history = vgg16.fit_generator(train_generator, steps_per_epoch=100, epochs=100, verbose=2, 
                              callbacks=callbacks, validation_data=val_generator, validation_steps=22)
_ = gc.collect()
# Out:
# Learning rate:  0.001
# Epoch 1/100
# Learning rate:  0.001
#  - 255s - loss: 2.7016 - acc: 0.4077 - val_loss: 2.5105 - val_acc: 0.4750
# Epoch 2/100
# Learning rate:  0.001
#  - 224s - loss: 1.8606 - acc: 0.5581 - val_loss: 2.2516 - val_acc: 0.5443
# Epoch 3/100
# Learning rate:  0.001
#  - 220s - loss: 1.7230 - acc: 0.5972 - val_loss: 2.1522 - val_acc: 0.5615
# Epoch 4/100
# Learning rate:  0.001
#  - 220s - loss: 1.6582 - acc: 0.6131 - val_loss: 2.1838 - val_acc: 0.5664
# Epoch 5/100
# Learning rate:  0.001
#  - 222s - loss: 1.6690 - acc: 0.6227 - val_loss: 2.1296 - val_acc: 0.5896
# Epoch 6/100
# Learning rate:  0.001
#  - 224s - loss: 1.6878 - acc: 0.6224 - val_loss: 1.9828 - val_acc: 0.6074
# Epoch 7/100
# Learning rate:  0.001
#  - 224s - loss: 1.6157 - acc: 0.6436 - val_loss: 2.1640 - val_acc: 0.6043
# Epoch 8/100
# Learning rate:  0.001
#  - 221s - loss: 1.5802 - acc: 0.6494 - val_loss: 2.0881 - val_acc: 0.6206
# Epoch 9/100
# Learning rate:  0.001
#  - 222s - loss: 1.5518 - acc: 0.6631 - val_loss: 2.0742 - val_acc: 0.6135
# Epoch 10/100
# Learning rate:  0.001
#  - 223s - loss: 1.5893 - acc: 0.6554 - val_loss: 2.0017 - val_acc: 0.6233
# Epoch 11/100
# Learning rate:  0.001
#  - 223s - loss: 1.5206 - acc: 0.6678 - val_loss: 1.9983 - val_acc: 0.6248
# Epoch 12/100
# Learning rate:  0.001
#  - 223s - loss: 1.5636 - acc: 0.6686 - val_loss: 1.9910 - val_acc: 0.6319
# Epoch 13/100
# Learning rate:  0.001
#  - 195s - loss: 0.7947 - acc: 0.8035 - val_loss: 1.9104 - val_acc: 0.6448
# Epoch 14/100
# Learning rate:  0.001
#  - 196s - loss: 0.7980 - acc: 0.8033 - val_loss: 1.9601 - val_acc: 0.6440
# Epoch 15/100
# Learning rate:  0.001
#  - 206s - loss: 0.8409 - acc: 0.7974 - val_loss: 1.8777 - val_acc: 0.6451
# Epoch 16/100
# Learning rate:  0.001
#  - 195s - loss: 0.8454 - acc: 0.7963 - val_loss: 1.8922 - val_acc: 0.6480
# Epoch 17/100
# Learning rate:  0.001
#  - 197s - loss: 0.8957 - acc: 0.7832 - val_loss: 1.9502 - val_acc: 0.6437
# Epoch 18/100
# Learning rate:  0.001
#  - 198s - loss: 0.9314 - acc: 0.7787 - val_loss: 2.0497 - val_acc: 0.6270
# Epoch 19/100
# Learning rate:  0.001
#  - 195s - loss: 0.9738 - acc: 0.7694 - val_loss: 1.9699 - val_acc: 0.6472
# Epoch 20/100
# Learning rate:  0.001
#  - 198s - loss: 0.9734 - acc: 0.7709 - val_loss: 2.0142 - val_acc: 0.6399
# Epoch 21/100
# Learning rate:  0.001
#  - 198s - loss: 0.9994 - acc: 0.7626 - val_loss: 1.9997 - val_acc: 0.6483
# Epoch 22/100
# Learning rate:  0.001
#  - 197s - loss: 1.0225 - acc: 0.7618 - val_loss: 2.1532 - val_acc: 0.6319
# Epoch 23/100
# Learning rate:  0.001
#  - 196s - loss: 1.0417 - acc: 0.7561 - val_loss: 2.0756 - val_acc: 0.6338
# Epoch 24/100
# Learning rate:  0.001
#  - 201s - loss: 1.0269 - acc: 0.7639 - val_loss: 2.0863 - val_acc: 0.6461
# Epoch 25/100
# Learning rate:  0.001
#  - 197s - loss: 0.5676 - acc: 0.8605 - val_loss: 1.9376 - val_acc: 0.6623
# Epoch 26/100
# Learning rate:  0.001
#  - 198s - loss: 0.5363 - acc: 0.8708 - val_loss: 1.8714 - val_acc: 0.6696
# Epoch 27/100
# Learning rate:  0.001
#  - 199s - loss: 0.5414 - acc: 0.8661 - val_loss: 1.8694 - val_acc: 0.6635
# Epoch 28/100
# Learning rate:  0.001
#  - 206s - loss: 0.5629 - acc: 0.8572 - val_loss: 1.9779 - val_acc: 0.6600
# Epoch 29/100
# Learning rate:  0.001
#  - 197s - loss: 0.5951 - acc: 0.8548 - val_loss: 1.9573 - val_acc: 0.6556
# Epoch 30/100
# Learning rate:  0.001
#  - 198s - loss: 0.6538 - acc: 0.8404 - val_loss: 2.0320 - val_acc: 0.6556
# Epoch 31/100
# Learning rate:  0.001
#  - 196s - loss: 0.6757 - acc: 0.8321 - val_loss: 2.0637 - val_acc: 0.6551
# Epoch 32/100
# Learning rate:  0.001
#  - 197s - loss: 0.6761 - acc: 0.8307 - val_loss: 2.0437 - val_acc: 0.6532
# Epoch 33/100
# Learning rate:  0.001
#  - 196s - loss: 0.6869 - acc: 0.8322 - val_loss: 2.0441 - val_acc: 0.6543
# Epoch 34/100
# Learning rate:  0.001
#  - 199s - loss: 0.7494 - acc: 0.8176 - val_loss: 2.1929 - val_acc: 0.6367
# Epoch 35/100
# Learning rate:  0.001
#  - 197s - loss: 0.7709 - acc: 0.8175 - val_loss: 2.1279 - val_acc: 0.6543
# Epoch 36/100
# Learning rate:  0.001
#  - 196s - loss: 0.7841 - acc: 0.8158 - val_loss: 2.0616 - val_acc: 0.6523
# Epoch 37/100
# Learning rate:  0.001
#  - 209s - loss: 0.3862 - acc: 0.9054 - val_loss: 2.0112 - val_acc: 0.6629
# Epoch 38/100
# Learning rate:  0.001
#  - 197s - loss: 0.4289 - acc: 0.9003 - val_loss: 2.0958 - val_acc: 0.6615
# Epoch 39/100
# Learning rate:  0.001
#  - 198s - loss: 0.4141 - acc: 0.9039 - val_loss: 2.0650 - val_acc: 0.6588
# Epoch 40/100
# Learning rate:  0.001
#  - 193s - loss: 0.4255 - acc: 0.8967 - val_loss: 2.0908 - val_acc: 0.6559
# Epoch 41/100
# Learning rate:  0.001
#  - 199s - loss: 0.4503 - acc: 0.8899 - val_loss: 2.0865 - val_acc: 0.6572
# Epoch 42/100
# Learning rate:  0.001
#  - 197s - loss: 0.5058 - acc: 0.8758 - val_loss: 2.2074 - val_acc: 0.6545
# Epoch 43/100
# Learning rate:  0.001
#  - 196s - loss: 0.5524 - acc: 0.8644 - val_loss: 2.1974 - val_acc: 0.6472
# Epoch 44/100
# Learning rate:  0.001
#  - 195s - loss: 0.5419 - acc: 0.8642 - val_loss: 2.2889 - val_acc: 0.6364
# Epoch 45/100
# Learning rate:  0.001
#  - 201s - loss: 0.5781 - acc: 0.8608 - val_loss: 2.3720 - val_acc: 0.6286
# Epoch 46/100
# Learning rate:  0.001
#  - 196s - loss: 0.6254 - acc: 0.8543 - val_loss: 2.1761 - val_acc: 0.6634
# Epoch 47/100
# Learning rate:  0.001
#  - 196s - loss: 0.6276 - acc: 0.8486 - val_loss: 2.2328 - val_acc: 0.6497
# Epoch 48/100
# Learning rate:  0.001
#  - 197s - loss: 0.6338 - acc: 0.8481 - val_loss: 2.2211 - val_acc: 0.6526
# Epoch 49/100
# Learning rate:  0.001
#  - 197s - loss: 0.3291 - acc: 0.9233 - val_loss: 2.0799 - val_acc: 0.6680
# Epoch 50/100
# Learning rate:  0.001
#  - 198s - loss: 0.3425 - acc: 0.9251 - val_loss: 2.1866 - val_acc: 0.6610
# Epoch 51/100
# Learning rate:  0.001
#  - 201s - loss: 0.3664 - acc: 0.9181 - val_loss: 2.1449 - val_acc: 0.6629
# Epoch 52/100
# Learning rate:  0.001
#  - 195s - loss: 0.3513 - acc: 0.9176 - val_loss: 2.1251 - val_acc: 0.6691
# Epoch 53/100
# Learning rate:  0.001
#  - 194s - loss: 0.3928 - acc: 0.9111 - val_loss: 2.2178 - val_acc: 0.6616
# Epoch 54/100
# Learning rate:  0.001
#  - 197s - loss: 0.3952 - acc: 0.9068 - val_loss: 2.1816 - val_acc: 0.6637
# Epoch 55/100
# Learning rate:  0.001
#  - 202s - loss: 0.4259 - acc: 0.8988 - val_loss: 2.3565 - val_acc: 0.6511
# Epoch 56/100
# Learning rate:  0.001
#  - 197s - loss: 0.4660 - acc: 0.8911 - val_loss: 2.2467 - val_acc: 0.6632
# Epoch 57/100
# Learning rate:  0.001
#  - 195s - loss: 0.5138 - acc: 0.8742 - val_loss: 2.3501 - val_acc: 0.6562
# Epoch 58/100
# Learning rate:  0.001
#  - 197s - loss: 0.4885 - acc: 0.8837 - val_loss: 2.3624 - val_acc: 0.6548
# Epoch 59/100
# Learning rate:  0.001
#  - 194s - loss: 0.5089 - acc: 0.8771 - val_loss: 2.3322 - val_acc: 0.6518
# Epoch 60/100
# Learning rate:  0.001
#  - 203s - loss: 0.5223 - acc: 0.8720 - val_loss: 2.3254 - val_acc: 0.6524
# Epoch 61/100
# Learning rate:  0.001
#  - 193s - loss: 0.3170 - acc: 0.9283 - val_loss: 2.1280 - val_acc: 0.6697
# Epoch 62/100
# Learning rate:  0.001
#  - 197s - loss: 0.2916 - acc: 0.9304 - val_loss: 2.2829 - val_acc: 0.6577
# Epoch 63/100
# Learning rate:  0.001
#  - 199s - loss: 0.3131 - acc: 0.9284 - val_loss: 2.2042 - val_acc: 0.6634
# Epoch 64/100
# Learning rate:  0.001
#  - 196s - loss: 0.3318 - acc: 0.9212 - val_loss: 2.2333 - val_acc: 0.6696
# Epoch 65/100
# Learning rate:  0.001
#  - 198s - loss: 0.3438 - acc: 0.9188 - val_loss: 2.2828 - val_acc: 0.6643
# Epoch 66/100
# Learning rate:  0.001
#  - 197s - loss: 0.3436 - acc: 0.9168 - val_loss: 2.3045 - val_acc: 0.6620
# Epoch 67/100
# Learning rate:  0.001
#  - 199s - loss: 0.3674 - acc: 0.9111 - val_loss: 2.2471 - val_acc: 0.6701
# Epoch 68/100
# Learning rate:  0.001
#  - 198s - loss: 0.3561 - acc: 0.9156 - val_loss: 2.2731 - val_acc: 0.6724
# Epoch 69/100
# Learning rate:  0.001
#  - 197s - loss: 0.3926 - acc: 0.9051 - val_loss: 2.2305 - val_acc: 0.6705
# Epoch 70/100
# Learning rate:  0.001
#  - 196s - loss: 0.4104 - acc: 0.9034 - val_loss: 2.2624 - val_acc: 0.6670
# Epoch 71/100
# Learning rate:  0.001
#  - 194s - loss: 0.4318 - acc: 0.8965 - val_loss: 2.3699 - val_acc: 0.6577
# Epoch 72/100
# Learning rate:  0.001
#  - 208s - loss: 0.4038 - acc: 0.9033 - val_loss: 2.3071 - val_acc: 0.6664
# Epoch 73/100
# Learning rate:  0.001
#  - 200s - loss: 0.2431 - acc: 0.9438 - val_loss: 2.3039 - val_acc: 0.6674
# Epoch 74/100
# Learning rate:  0.001
#  - 193s - loss: 0.2820 - acc: 0.9383 - val_loss: 2.3043 - val_acc: 0.6694
# Epoch 75/100
# Learning rate:  0.001
#  - 196s - loss: 0.2758 - acc: 0.9383 - val_loss: 2.3058 - val_acc: 0.6728
# Epoch 76/100
# Learning rate:  0.001
#  - 199s - loss: 0.2899 - acc: 0.9367 - val_loss: 2.3311 - val_acc: 0.6693
# Epoch 77/100
# Learning rate:  0.001
#  - 215s - loss: 0.2824 - acc: 0.9350 - val_loss: 2.3866 - val_acc: 0.6669
# Epoch 78/100
# Learning rate:  0.001
#  - 197s - loss: 0.3152 - acc: 0.9244 - val_loss: 2.3330 - val_acc: 0.6696
# Epoch 79/100
# Learning rate:  0.001
#  - 198s - loss: 0.3386 - acc: 0.9234 - val_loss: 2.3425 - val_acc: 0.6742
# Epoch 80/100
# Learning rate:  0.001
#  - 202s - loss: 0.3358 - acc: 0.9194 - val_loss: 2.5003 - val_acc: 0.6575
# Epoch 81/100
# Learning rate:  0.001
#  - 195s - loss: 0.3443 - acc: 0.9163 - val_loss: 2.2980 - val_acc: 0.6709
# Epoch 82/100
# Learning rate:  0.0001
#  - 197s - loss: 0.2148 - acc: 0.9532 - val_loss: 2.1061 - val_acc: 0.6955
# Epoch 83/100
# Learning rate:  0.0001
#  - 195s - loss: 0.2050 - acc: 0.9597 - val_loss: 2.0800 - val_acc: 0.6949
# Epoch 84/100
# Learning rate:  0.0001
#  - 195s - loss: 0.1884 - acc: 0.9641 - val_loss: 2.0848 - val_acc: 0.6990
# Epoch 85/100
# Learning rate:  0.0001
#  - 195s - loss: 0.1565 - acc: 0.9818 - val_loss: 2.0563 - val_acc: 0.6998
# Epoch 86/100
# Learning rate:  0.0001
#  - 196s - loss: 0.1353 - acc: 0.9830 - val_loss: 2.0548 - val_acc: 0.6980
# Epoch 87/100
# Learning rate:  0.0001
#  - 197s - loss: 0.1382 - acc: 0.9814 - val_loss: 2.0647 - val_acc: 0.6998
# Epoch 88/100
# Learning rate:  0.0001
#  - 198s - loss: 0.1353 - acc: 0.9833 - val_loss: 2.0609 - val_acc: 0.7015
# Epoch 89/100
# Learning rate:  0.0001
#  - 196s - loss: 0.1293 - acc: 0.9829 - val_loss: 2.0518 - val_acc: 0.7010
# Epoch 90/100
# Learning rate:  0.0001
#  - 204s - loss: 0.1254 - acc: 0.9835 - val_loss: 2.0537 - val_acc: 0.7006
# Epoch 91/100
# Learning rate:  0.0001
#  - 197s - loss: 0.1331 - acc: 0.9844 - val_loss: 2.0470 - val_acc: 0.7017
# Epoch 92/100
# Learning rate:  0.0001
#  - 195s - loss: 0.1359 - acc: 0.9834 - val_loss: 2.0369 - val_acc: 0.7053
# Epoch 93/100
# Learning rate:  0.0001
#  - 196s - loss: 0.1239 - acc: 0.9830 - val_loss: 2.0211 - val_acc: 0.7041
# Epoch 94/100
# Learning rate:  0.0001
#  - 197s - loss: 0.1325 - acc: 0.9832 - val_loss: 2.0211 - val_acc: 0.7055
# Epoch 95/100
# Learning rate:  0.0001
#  - 198s - loss: 0.1422 - acc: 0.9829 - val_loss: 2.0311 - val_acc: 0.7041
# Epoch 96/100
# Learning rate:  0.0001
#  - 197s - loss: 0.1506 - acc: 0.9811 - val_loss: 2.0182 - val_acc: 0.7036
# Epoch 97/100
# Learning rate:  0.0001
#  - 198s - loss: 0.1408 - acc: 0.9875 - val_loss: 2.0133 - val_acc: 0.7015
# Epoch 98/100
# Learning rate:  0.0001
#  - 195s - loss: 0.1132 - acc: 0.9871 - val_loss: 2.0117 - val_acc: 0.7063
# Epoch 99/100
# Learning rate:  0.0001
#  - 197s - loss: 0.1235 - acc: 0.9880 - val_loss: 2.0190 - val_acc: 0.7042
# Epoch 100/100
# Learning rate:  0.0001
#  - 196s - loss: 0.1211 - acc: 0.9877 - val_loss: 2.0321 - val_acc: 0.7057

# %%
# Visualize the training process
train_loss = history.history['loss']
train_acc = history.history['acc']
val_loss = history.history['val_loss']
val_acc = history.history['val_acc']

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 7))
ax[0].plot(train_loss, label='Training Loss')
ax[0].plot(val_loss, label='Validation Loss')
ax[0].set_title('Loss vs. Epochs', fontsize=16)
ax[0].set_xlabel('Epochs', fontsize=14)
ax[0].set_ylabel('Loss', fontsize=14)
ax[0].legend(fontsize=14)
ax[0].grid(True)

ax[1].plot(train_acc, label='Train Accuracy')
ax[1].plot(val_acc, label='Val Accuracy')
ax[1].set_title('Accuracy vs. Epochs', fontsize=16)
ax[1].set_xlabel('Epochs', fontsize=14)
ax[1].set_ylabel('Accuracy', fontsize=14)
ax[1].legend(fontsize=14)
ax[1].grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Make Predictions

# %%
# Load test images
test_ids = []
test_images = []
for idx in test_df['id'].values:
    if os.path.exists('./data/test/' + str(idx) + '.jpg'):
        img = Image.open('./data/test/' + str(idx) + '.jpg')
        if img.mode != 'RGB':
            img = img.convert('RGB')
        img = img.resize((224, 224))
        img = np.asarray(img, dtype=K.floatx())
        test_images.append(img)
        test_ids.append(idx)

# Re-scale the images
test_images = np.array(test_images, dtype=K.floatx())
test_images = test_images / 255.0

# %%
# Load the saved model
vgg16 = load_model('./models/vgg16-1-layer-initial.h5')

# Make predictions
test_pred = vgg16.predict(test_images)
test_label = np.argmax(test_pred, axis=1) + 1

# %%
# Sample submission
sample_submission = pd.read_csv('./data/sample_submission.csv', usecols=['id'])
df_submission = pd.DataFrame({'id': test_ids, 'predicted': test_label})

# Merge together
df_submission = pd.merge(sample_submission, df_submission, how='left', on='id')

# Fill missing values
n = df_submission['predicted'].isnull().sum()
guess = np.random.choice(range(1, 129), n, replace=True)
df_submission.loc[df_submission['predicted'].isnull(), 'predicted'] = guess

df_submission['predicted'] = df_submission['predicted'].astype(int)

# Save to disk
df_submission.to_csv('./result/vgg16-1-layer-initial.csv', columns=['id', 'predicted'], index=False)

_ = gc.collect()

# %% [markdown]
# # VGG16 Fune-tuning
