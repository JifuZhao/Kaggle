# %% [markdown]
# # Simple Logistic Regression Analysis
# * Data: Titanic Disaster Survival Data from Kaggle
# * Link: [survival data](https://www.kaggle.com/c/titanic)

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn
import re
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %matplotlib inline

print('Scikit-learn:\t', sklearn.__version__)
print('Numpy:\t\t', np.__version__)
print('Pandas:\t\t', pd.__version__)
print('Matplotlib:\t', mpl.__version__)
# Out:
# Scikit-learn:	 0.19.0
# Numpy:		 1.13.1
# Pandas:		 0.20.3
# Matplotlib:	 2.0.2

# %% [markdown]
# ## Read Data

# %%
train = pd.read_csv('./data/Titanic_Data/train.csv')
test = pd.read_csv('./data/Titanic_Data/test.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
# Null values
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
# define numerical and categorical variables
num_cols = ['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
cat_cols = ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
for name in num_cols:
    print('{0:12s} train: {1:5d} \t test: {2:5d}'.format(name, len(train[name].unique()), 
                                                         len(test[name].unique())))
# Out:
# PassengerId  train:   891 	 test:   418
# Pclass       train:     3 	 test:     3
# Age          train:    89 	 test:    80
# SibSp        train:     7 	 test:     7
# Parch        train:     7 	 test:     8
# Fare         train:   248 	 test:   170

# %%
# unique values
for name in cat_cols:
    print('{0:12s} train: {1:5d} \t test: {2:5d}'.format(name, len(train[name].unique()), 
                                                         len(test[name].unique())))
# Out:
# Name         train:   891 	 test:   418
# Sex          train:     2 	 test:     2
# Ticket       train:   681 	 test:   363
# Cabin        train:   148 	 test:    77
# Embarked     train:     4 	 test:     3

# %%
train.groupby(['Pclass']).count().sort_index() / len(train)
# Out:
#         PassengerId  Survived      Name       Sex       Age     SibSp  \
# Pclass
# 1          0.242424  0.242424  0.242424  0.242424  0.208754  0.242424
# 2          0.206510  0.206510  0.206510  0.206510  0.194164  0.206510
# 3          0.551066  0.551066  0.551066  0.551066  0.398429  0.551066
#
#            Parch    Ticket      Fare     Cabin  Embarked
# Pclass
# 1       0.242424  0.242424  0.242424  0.197531  0.240180
# 2       0.206510  0.206510  0.206510  0.017957  0.206510
# 3       0.551066  0.551066  0.551066  0.013468  0.551066

# %%
test.groupby(['Pclass']).count().sort_index() / len(test)
# Out:
#         PassengerId      Name       Sex       Age     SibSp     Parch  \
# Pclass
# 1          0.255981  0.255981  0.255981  0.234450  0.255981  0.255981
# 2          0.222488  0.222488  0.222488  0.210526  0.222488  0.222488
# 3          0.521531  0.521531  0.521531  0.349282  0.521531  0.521531
#
#           Ticket      Fare     Cabin  Embarked
# Pclass
# 1       0.255981  0.255981  0.191388  0.255981
# 2       0.222488  0.222488  0.016746  0.222488
# 3       0.521531  0.519139  0.009569  0.521531

# %%
train.groupby(['SibSp']).count().sort_index() / len(train)
# Out:
#        PassengerId  Survived    Pclass      Name       Sex       Age  \
# SibSp
# 0         0.682379  0.682379  0.682379  0.682379  0.682379  0.528620
# 1         0.234568  0.234568  0.234568  0.234568  0.234568  0.205387
# 2         0.031425  0.031425  0.031425  0.031425  0.031425  0.028058
# 3         0.017957  0.017957  0.017957  0.017957  0.017957  0.013468
# 4         0.020202  0.020202  0.020202  0.020202  0.020202  0.020202
# 5         0.005612  0.005612  0.005612  0.005612  0.005612  0.005612
# 8         0.007856  0.007856  0.007856  0.007856  0.007856  0.000000
#
#           Parch    Ticket      Fare     Cabin  Embarked
# SibSp
# 0      0.682379  0.682379  0.682379  0.141414  0.680135
# 1      0.234568  0.234568  0.234568  0.077441  0.234568
# 2      0.031425  0.031425  0.031425  0.006734  0.031425
# 3      0.017957  0.017957  0.017957  0.003367  0.017957
# 4      0.020202  0.020202  0.020202  0.000000  0.020202
# 5      0.005612  0.005612  0.005612  0.000000  0.005612
# 8      0.007856  0.007856  0.007856  0.000000  0.007856

# %%
test.groupby(['SibSp']).count().sort_index() / len(test)
# Out:
#        PassengerId    Pclass      Name       Sex       Age     Parch  \
# SibSp
# 0         0.677033  0.677033  0.677033  0.677033  0.511962  0.677033
# 1         0.263158  0.263158  0.263158  0.263158  0.232057  0.263158
# 2         0.033493  0.033493  0.033493  0.033493  0.026316  0.033493
# 3         0.009569  0.009569  0.009569  0.009569  0.009569  0.009569
# 4         0.009569  0.009569  0.009569  0.009569  0.009569  0.009569
# 5         0.002392  0.002392  0.002392  0.002392  0.002392  0.002392
# 8         0.004785  0.004785  0.004785  0.004785  0.002392  0.004785
#
#          Ticket      Fare     Cabin  Embarked
# SibSp
# 0      0.677033  0.674641  0.107656  0.677033
# 1      0.263158  0.263158  0.098086  0.263158
# 2      0.033493  0.033493  0.009569  0.033493
# 3      0.009569  0.009569  0.002392  0.009569
# 4      0.009569  0.009569  0.000000  0.009569
# 5      0.002392  0.002392  0.000000  0.002392
# 8      0.004785  0.004785  0.000000  0.004785

# %%
train.groupby(['Parch']).count().sort_index() / len(train)
# Out:
#        PassengerId  Survived    Pclass      Name       Sex       Age  \
# Parch
# 0         0.760943  0.760943  0.760943  0.760943  0.760943  0.584736
# 1         0.132435  0.132435  0.132435  0.132435  0.132435  0.123457
# 2         0.089787  0.089787  0.089787  0.089787  0.089787  0.076319
# 3         0.005612  0.005612  0.005612  0.005612  0.005612  0.005612
# 4         0.004489  0.004489  0.004489  0.004489  0.004489  0.004489
# 5         0.005612  0.005612  0.005612  0.005612  0.005612  0.005612
# 6         0.001122  0.001122  0.001122  0.001122  0.001122  0.001122
#
#           SibSp    Ticket      Fare     Cabin  Embarked
# Parch
# 0      0.760943  0.760943  0.760943  0.158249  0.758698
# 1      0.132435  0.132435  0.132435  0.043771  0.132435
# 2      0.089787  0.089787  0.089787  0.025814  0.089787
# 3      0.005612  0.005612  0.005612  0.000000  0.005612
# 4      0.004489  0.004489  0.004489  0.001122  0.004489
# 5      0.005612  0.005612  0.005612  0.000000  0.005612
# 6      0.001122  0.001122  0.001122  0.000000  0.001122

# %%
test.groupby(['Parch']).count().sort_index() / len(test)
# Out:
#        PassengerId    Pclass      Name       Sex       Age     SibSp  \
# Parch
# 0         0.775120  0.775120  0.775120  0.775120  0.590909  0.775120
# 1         0.124402  0.124402  0.124402  0.124402  0.119617  0.124402
# 2         0.078947  0.078947  0.078947  0.078947  0.069378  0.078947
# 3         0.007177  0.007177  0.007177  0.007177  0.007177  0.007177
# 4         0.004785  0.004785  0.004785  0.004785  0.002392  0.004785
# 5         0.002392  0.002392  0.002392  0.002392  0.002392  0.002392
# 6         0.002392  0.002392  0.002392  0.002392  0.002392  0.002392
# 9         0.004785  0.004785  0.004785  0.004785  0.000000  0.004785
#
#          Ticket      Fare     Cabin  Embarked
# Parch
# 0      0.775120  0.772727  0.153110  0.775120
# 1      0.124402  0.124402  0.040670  0.124402
# 2      0.078947  0.078947  0.014354  0.078947
# 3      0.007177  0.007177  0.007177  0.007177
# 4      0.004785  0.004785  0.002392  0.004785
# 5      0.002392  0.002392  0.000000  0.002392
# 6      0.002392  0.002392  0.000000  0.002392
# 9      0.004785  0.004785  0.000000  0.004785

# %%
train.groupby(['Sex']).count().sort_index() / len(train)
# Out:
#         PassengerId  Survived    Pclass      Name       Age     SibSp  \
# Sex
# female     0.352413  0.352413  0.352413  0.352413  0.292929  0.352413
# male       0.647587  0.647587  0.647587  0.647587  0.508418  0.647587
#
#            Parch    Ticket      Fare     Cabin  Embarked
# Sex
# female  0.352413  0.352413  0.352413  0.108866  0.350168
# male    0.647587  0.647587  0.647587  0.120090  0.647587

# %%
test.groupby(['Sex']).count().sort_index() / len(test)
# Out:
#         PassengerId    Pclass      Name       Age     SibSp     Parch  \
# Sex
# female     0.363636  0.363636  0.363636  0.303828  0.363636  0.363636
# male       0.636364  0.636364  0.636364  0.490431  0.636364  0.636364
#
#           Ticket      Fare     Cabin  Embarked
# Sex
# female  0.363636  0.363636  0.105263  0.363636
# male    0.636364  0.633971  0.112440  0.636364

# %%
train.groupby(['Embarked']).count().sort_index() / len(train)
# Out:
#           PassengerId  Survived    Pclass      Name       Sex       Age  \
# Embarked
# C            0.188552  0.188552  0.188552  0.188552  0.188552  0.145903
# Q            0.086420  0.086420  0.086420  0.086420  0.086420  0.031425
# S            0.722783  0.722783  0.722783  0.722783  0.722783  0.621773
#
#              SibSp     Parch    Ticket      Fare     Cabin
# Embarked
# C         0.188552  0.188552  0.188552  0.188552  0.077441
# Q         0.086420  0.086420  0.086420  0.086420  0.004489
# S         0.722783  0.722783  0.722783  0.722783  0.144781

# %%
test.groupby(['Embarked']).count().sort_index() / len(test)
# Out:
#           PassengerId    Pclass      Name       Sex       Age     SibSp  \
# Embarked
# C            0.244019  0.244019  0.244019  0.244019  0.196172  0.244019
# Q            0.110048  0.110048  0.110048  0.110048  0.052632  0.110048
# S            0.645933  0.645933  0.645933  0.645933  0.545455  0.645933
#
#              Parch    Ticket      Fare     Cabin
# Embarked
# C         0.244019  0.244019  0.244019  0.117225
# Q         0.110048  0.110048  0.110048  0.002392
# S         0.645933  0.645933  0.643541  0.098086

# %% [markdown]
# ## Feature Engineering

# %%
# combine train and test data
all_data = pd.concat([train, test])

# %%
all_data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
all_data.tail()
# Out:
#       Age Cabin Embarked      Fare                          Name  Parch  \
# 413   NaN   NaN        S    8.0500            Spector, Mr. Woolf      0
# 414  39.0  C105        C  108.9000  Oliva y Ocana, Dona. Fermina      0
# 415  38.5   NaN        S    7.2500  Saether, Mr. Simon Sivertsen      0
# 416   NaN   NaN        S    8.0500           Ware, Mr. Frederick      0
# 417   NaN   NaN        C   22.3583      Peter, Master. Michael J      1
#
#      PassengerId  Pclass     Sex  SibSp  Survived              Ticket
# 413         1305       3    male      0       NaN           A.5. 3236
# 414         1306       1  female      0       NaN            PC 17758
# 415         1307       3    male      0       NaN  SOTON/O.Q. 3101262
# 416         1308       3    male      0       NaN              359309
# 417         1309       3    male      1       NaN                2668

# %%
# create Title variable
all_data['Title'] = all_data['Name'].apply(lambda x: re.split('[.,]', x)[1].strip())
pd.crosstab(all_data['Title'], all_data['Sex'])
# Out:
# Sex           female  male
# Title
# Capt               0     1
# Col                0     4
# Don                0     1
# Dona               1     0
# Dr                 1     7
# Jonkheer           0     1
# Lady               1     0
# Major              0     2
# Master             0    61
# Miss             260     0
# Mlle               2     0
# Mme                1     0
# Mr                 0   757
# Mrs              197     0
# Ms                 2     0
# Rev                0     8
# Sir                0     1
# the Countess       1     0

# %%
# one special case
all_data.loc[(all_data['Sex'] == 'female') & (all_data['Title'] == 'Dr'), 'Title'] = 'Mrs'

# %%
# manually fix the title error
male_name = ['Capt', 'Col', 'Don', 'Jonkheer', 'Major', 'Rev', 'Sir', 'Dr']
famale_name = ['Dona', 'Lady', 'Mlle', 'Mme', 'Ms', 'the Countess']
all_data['Title'].replace(male_name, 'Mr', inplace=True)
all_data['Title'].replace(famale_name, 'Mrs', inplace=True)

# %%
# encoder Title column
le = LabelEncoder()
all_data['Title'] = le.fit_transform(all_data['Title'])

# %%
pd.crosstab(all_data['Title'], all_data['Sex'])
# Out:
# Sex    female  male
# Title
# 0           0    61
# 1         260     0
# 2           0   782
# 3         206     0

# %%
# encoder the sex column
all_data['Sex'] = (all_data['Sex'] == 'male').astype('int')

# %%
# create Ticket binary variable
all_data['abs_col'] = (all_data['Ticket'].apply(lambda x: len(x.split())) > 1).astype(int)

# %% [markdown]
# ### fill NA values

# %%
# replace missing Age with median
all_data.loc[all_data['Age'].isnull(), 'Age'] = all_data['Age'].median(skipna=True)

# %%
# # drop missing value for Embarked
# all_data = all_data[~all_data['Embarked'].isnull()]

# %%
# replace missing Fare with median
all_data.loc[all_data['Fare'].isnull(), 'Fare'] = all_data['Fare'].median(skipna=True)

# %%
# completely drop Cabin
all_data = all_data.drop(['Cabin', 'Name', 'Ticket', 'PassengerId', 'Embarked'], axis=1)

# %%
# transform Age into log
all_data['Fare'] = np.log(all_data['Fare'] + 1)

# %%
all_data.isnull().sum()
# Out:
# Age           0
# Fare          0
# Parch         0
# Pclass        0
# Sex           0
# SibSp         0
# Survived    418
# Title         0
# abs_col       0
# dtype: int64

# %%
# change Paerch == 9 to be 0
all_data.loc[all_data['Parch'] == 9, 'Parch'] = 0

# %%
all_data.head()
# Out:
#     Age      Fare  Parch  Pclass  Sex  SibSp  Survived  Title  abs_col
# 0  22.0  2.110213      0       3    1      1       0.0      2        1
# 1  38.0  4.280593      0       1    0      1       1.0      3        1
# 2  26.0  2.188856      0       3    0      0       1.0      1        1
# 3  35.0  3.990834      0       1    0      1       1.0      3        0
# 4  35.0  2.202765      0       3    1      0       0.0      2        0

# %%
all_data.tail()
# Out:
#       Age      Fare  Parch  Pclass  Sex  SibSp  Survived  Title  abs_col
# 413  28.0  2.202765      0       3    1      0       NaN      2        1
# 414  39.0  4.699571      0       1    0      0       NaN      3        1
# 415  38.5  2.110213      0       3    1      0       NaN      2        1
# 416  28.0  2.202765      0       3    1      0       NaN      2        0
# 417  28.0  3.150952      1       3    1      1       NaN      0        0

# %%
# get train and test data set
train_tmp = all_data[~all_data['Survived'].isnull()]
test_tmp = all_data[all_data['Survived'].isnull()]

# %% [markdown]
# ## Fit logistic regression model

# %%
train_x = train_tmp[['Age', 'Fare', 'Parch', 'Pclass', 'Sex', 'SibSp', 'Title', 'abs_col']]
train_y = train_tmp['Survived']
test_x = test_tmp[['Age', 'Fare', 'Parch', 'Pclass', 'Sex', 'SibSp', 'Title', 'abs_col']]

# %%
model = LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=1.0, fit_intercept=True, 
                           intercept_scaling=1, class_weight=None, random_state=None, 
                           solver='liblinear', max_iter=100, multi_class='ovr', 
                           verbose=0, warm_start=False, n_jobs=1)

model.fit(train_x, train_y)

train_y_pred = model.predict(train_x).astype(int)
test_y_pred = model.predict(test_x).astype(int)
train_y_prob = model.predict_proba(train_x)[:, 1]
test_y_prob = model.predict_proba(test_x)[:, 1]

# %%
model.score(train_x, train_y)
# Out:
# 0.79797979797979801

# %%
# Make submission file
result = pd.DataFrame({'PassengerId': test['PassengerId'], 'Survived': test_y_pred})
result.to_csv('./results/Titanic.csv', index=False)

# %% [markdown]
# ## Cross validation

# %%
train_x = train_tmp[['Age', 'Fare', 'Parch', 'Pclass', 'Sex', 'SibSp', 'Title', 'abs_col']]
train_y = train_tmp['Survived']
test_x = test_tmp[['Age', 'Fare', 'Parch', 'Pclass', 'Sex', 'SibSp', 'Title', 'abs_col']]

# %%
model = LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=1.0, fit_intercept=True, 
                           intercept_scaling=1, class_weight=None, random_state=None, 
                           solver='liblinear', max_iter=100, multi_class='ovr', 
                           verbose=0, warm_start=False, n_jobs=1)
scores = cross_val_score(model, train_x, train_y, cv=5, scoring='accuracy')
print('Accuracy:\t', *scores)
# Out:
# Accuracy:	 0.782122905028 0.793296089385 0.775280898876 0.780898876404 0.813559322034

# %%
model = LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=1.0, fit_intercept=True, 
                           intercept_scaling=1, class_weight=None, random_state=None, 
                           solver='liblinear', max_iter=100, multi_class='ovr', 
                           verbose=0, warm_start=False, n_jobs=1)
scores = cross_val_score(model, train_x, train_y, cv=5, scoring='roc_auc')
print('AUC:\t', *scores)
# Out:
# AUC:	 0.836890645586 0.836956521739 0.840240641711 0.849398395722 0.88262277388

# %%
for i in np.linspace(0, 1, 100):
    pred = (train_y_prob > i).astype(int)
    accuracy = np.sum(pred == train_y) / len(pred)
    print(i, '\t', accuracy)
# Out:
# 0.0 	 0.383838383838
# 0.010101010101 	 0.388327721661
# 0.020202020202 	 0.389450056117
# 0.030303030303 	 0.391694725028
# 0.040404040404 	 0.396184062851
# 0.0505050505051 	 0.414141414141
# 0.0606060606061 	 0.420875420875
# 0.0707070707071 	 0.443322109989
# 0.0808080808081 	 0.460157126824
# 0.0909090909091 	 0.485970819304
# 0.10101010101 	 0.514029180696
# 0.111111111111 	 0.593714927048
# 0.121212121212 	 0.631874298541
# 0.131313131313 	 0.664421997755
# 0.141414141414 	 0.683501683502
# 0.151515151515 	 0.693602693603
# 0.161616161616 	 0.708193041526
# 0.171717171717 	 0.712682379349
# 0.181818181818 	 0.725028058361
# 0.191919191919 	 0.728395061728
# 0.20202020202 	 0.738496071829
# 0.212121212121 	 0.738496071829
# 0.222222222222 	 0.744107744108
# 0.232323232323 	 0.74859708193
# 0.242424242424 	 0.755331088664
# 0.252525252525 	 0.762065095398
# 0.262626262626 	 0.771043771044
# 0.272727272727 	 0.775533108866
# 0.282828282828 	 0.776655443322
# 0.292929292929 	 0.778900112233
# 0.30303030303 	 0.778900112233
# 0.313131313131 	 0.778900112233
# 0.323232323232 	 0.7822671156
# 0.333333333333 	 0.7822671156
# 0.343434343434 	 0.778900112233
# 0.353535353535 	 0.780022446689
# 0.363636363636 	 0.783389450056
# 0.373737373737 	 0.7822671156
# 0.383838383838 	 0.784511784512
# 0.393939393939 	 0.786756453423
# 0.40404040404 	 0.789001122334
# 0.414141414141 	 0.783389450056
# 0.424242424242 	 0.7822671156
# 0.434343434343 	 0.792368125701
# 0.444444444444 	 0.793490460157
# 0.454545454545 	 0.796857463524
# 0.464646464646 	 0.793490460157
# 0.474747474747 	 0.794612794613
# 0.484848484848 	 0.794612794613
# 0.494949494949 	 0.795735129068
# 0.505050505051 	 0.796857463524
# 0.515151515152 	 0.79797979798
# 0.525252525253 	 0.799102132435
# 0.535353535354 	 0.800224466891
# 0.545454545455 	 0.805836139169
# 0.555555555556 	 0.799102132435
# 0.565656565657 	 0.802469135802
# 0.575757575758 	 0.803591470258
# 0.585858585859 	 0.804713804714
# 0.59595959596 	 0.803591470258
# 0.606060606061 	 0.803591470258
# 0.616161616162 	 0.801346801347
# 0.626262626263 	 0.801346801347
# 0.636363636364 	 0.804713804714
# 0.646464646465 	 0.804713804714
# 0.656565656566 	 0.804713804714
# 0.666666666667 	 0.787878787879
# 0.676767676768 	 0.783389450056
# 0.686868686869 	 0.7822671156
# 0.69696969697 	 0.772166105499
# 0.707070707071 	 0.769921436588
# 0.717171717172 	 0.76430976431
# 0.727272727273 	 0.768799102132
# 0.737373737374 	 0.763187429854
# 0.747474747475 	 0.758698092031
# 0.757575757576 	 0.757575757576
# 0.767676767677 	 0.755331088664
# 0.777777777778 	 0.750841750842
# 0.787878787879 	 0.749719416386
# 0.79797979798 	 0.746352413019
# 0.808080808081 	 0.741863075196
# 0.818181818182 	 0.734006734007
# 0.828282828283 	 0.727272727273
# 0.838383838384 	 0.720538720539
# 0.848484848485 	 0.713804713805
# 0.858585858586 	 0.710437710438
# 0.868686868687 	 0.709315375982
# 0.878787878788 	 0.701459034792
# 0.888888888889 	 0.691358024691
# 0.89898989899 	 0.683501683502
# 0.909090909091 	 0.679012345679
# 0.919191919192 	 0.673400673401
# 0.929292929293 	 0.668911335578
# 0.939393939394 	 0.659932659933
# 0.949494949495 	 0.645342312009
# 0.959595959596 	 0.638608305275
# 0.969696969697 	 0.622895622896
# 0.979797979798 	 0.618406285073
# 0.989898989899 	 0.616161616162
# 1.0 	 0.616161616162

# %%
# Make submission file
pred = (test_y_prob > 0.545454545455).astype(int)
result = pd.DataFrame({'PassengerId': test['PassengerId'], 'Survived': pred})
result.to_csv('./results/Titanic2.csv', index=False)
